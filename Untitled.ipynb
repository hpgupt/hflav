# %%
import json

# %%
f = open('gsoc_hflav2.json')

# %%
data = json.load(f)

# %%
data
# Out:
# [{'name': 'BR_Lambdab0_K-_D0_p.-BR_Lambdab0_pi-_D0_p',
#   'latex': '\\frac{{\\cal{B}} ( \\Lambda_b^{0} \\to D^{0} p K^{-} ) }{ {\\cal{B}} ( \\Lambda_b^{0} \\to D^{0} p \\pi^{-} )}',
#   'category': 'Bbaryon/D',
#   'average': 0.07840881240362992,
#   'error': 0.008607155901120699,
#   'measurements': [{'value': 0.073, 'error': 0.011169491020860955},
#    {'value': 0.112, 'error': 0.025998451891820918}]},
#  {'name': 'BR_Lambdab0_D0_p_pi.BR_D0_K_pi.-BR_Lambdab0_Lambdac_pi.BR_Lambdac_p_K_pi',
#   'latex': '\\frac{ {\\cal{B}} ( \\Lambda_b^{0} \\to D^{0} p \\pi^{-})  \\times {\\cal{B}} ( D^{0} \\to K^{+} \\pi^{-} )} {  {\\cal{B}} ( \\Lambda_b^{0} \\to \\Lambda_c^{+} \\pi^{-} )   \\times   {\\cal{B}}  (\\Lambda_c^{+} \\to  p K^{-} \\pi^{+}) }',
#   'category': 'Bbaryon/D',
#   'average': 0.0806,
#   'error': 0.004188078318274384,
#   'measurements': [{'value': 0.0806, 'error': 0.0054580216195980755}]},
#  {'name': 'f_Xib0.BR_Xib0_D0_p_K-f_Lambdab0.BR_Lambdab0_D0_p_K',
# ...

# %%
for d in data:
    d['latex']= '$ '+d['latex']+' $'
    print (d['latex'])
# Out:
# $ \frac{{\cal{B}} ( \Lambda_b^{0} \to D^{0} p K^{-} ) }{ {\cal{B}} ( \Lambda_b^{0} \to D^{0} p \pi^{-} )} $
# $ \frac{ {\cal{B}} ( \Lambda_b^{0} \to D^{0} p \pi^{-})  \times {\cal{B}} ( D^{0} \to K^{+} \pi^{-} )} {  {\cal{B}} ( \Lambda_b^{0} \to \Lambda_c^{+} \pi^{-} )   \times   {\cal{B}}  (\Lambda_c^{+} \to  p K^{-} \pi^{+}) } $
# $ \frac{ f_{\Xi_b^{0}} \times{\cal{B}} ( \Xi_b^{0} \to D^{0} p K^{-} )   } { f_{\Lambda_b^{0}} \times{\cal{B}} ( \Lambda_b^{0} \to D^{0} p K^{-})  } $
# $ \frac{ {\cal{B}}( \Lambda_b^0 \to \chi_{c2} p K^- ) }{ {\cal{B}}( \Lambda_b^0 \to \chi_{c1} p K^- ) } $
# $ {\cal{B}} ( \Lambda_b^{0} \to J/\psi p K^{-} ) $
# $ \frac{{\cal{B}} ( \Lambda_b^{0} \to \psi(2S) \Lambda )}{{\cal{B}} ( \Lambda_b^{0} \to J/\psi \Lambda )} $
# $ {f_{\Lambda_b} \times \cal{B}} ( \Lambda_b^{0} \to J/\psi \Lambda ) $
# $ \frac{f_{\Omega_b^{-}} \times {\cal{B}} ( \Omega_b^{-} \to J/\psi \Omega^{-} ) }{ f_{\Lambda_b^{0}}  \times   {\cal{B}} ( \Lambda_b^{0} \to J/\psi \Lambda )} $
# ...

# %%
out_file = open("gsoc_hflav2.json", "w")

# %%
json.dump(data, out_file, indent = 6)

# %%
out_file.close()
